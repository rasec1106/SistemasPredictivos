# %%
# Libreria para RNA
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
celsius = np.array([32, 24, 16, 9, 0, -8, -32], dtype=float)        #input x
fahrenheit = np.array([90, 75, 61, 48, 32, 18, -26], dtype=float)   #output y

# %%
oculta1 = tf.keras.layers.Dense(units=3, input_shape=[1])
oculta2 = tf.keras.layers.Dense(units=3)
salida = tf.keras.layers.Dense(units=1)
modelo = tf.keras.Sequential([oculta1, oculta2, salida])

# %%
# Optimizador Adam permite ajustar los pesos y sesgos
# Tasa de aprendizaje 0.1 (un valor bajo aprende lentamente, valor grande aprende rápido pero no seria muy fino el resultado)
# mean_squared_error MSE es la funcion de perdida
modelo.compile(
    optimizer=tf.keras.optimizers.Adam(0.1),
    loss='mean_squared_error'
)

# %%
print("Entrenando el modelo...")
historial = modelo.fit(celsius, fahrenheit, epochs=1000, verbose=False)
print("Modelo entrenado.")
# Out:
# Entrenando el modelo...
# Modelo entrenado.

# %%
import matplotlib.pyplot as plt
plt.plot(historial.history['loss'])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %%
print("Realizando predicciones...")
predicciones = modelo.predict(np.array([100]))
print("Predicción para 100 grados Celsius:", predicciones[0][0])
# Out:
# Realizando predicciones...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicción para 100 grados Celsius: 212.63174
